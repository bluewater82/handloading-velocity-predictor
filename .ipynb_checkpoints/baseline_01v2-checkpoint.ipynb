# %% [markdown]
# ### Sanity check v2
# - With updated dataset we will again do a limited-scope model using just two hard features (bullet mass and amount of propellant) to verify the physics are correctly working before expanding the amount of features

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/baseline_data_updated.csv")
df.head(20)
# Out:
#    cartridge  bullet_diameter bullet_brand      bullet_type  bullet_weight  \
# 0    223_rem            0.225       barnes             hpfb           36.0
# 1    223_rem            0.225       barnes             hpfb           36.0
# 2    223_rem            0.225       barnes             hpfb           36.0
# 3    223_rem            0.225       barnes             hpfb           36.0
# 4    223_rem            0.225       barnes             hpfb           36.0
# 5    223_rem            0.225       barnes  varmint_grenade           50.0
# 6    223_rem            0.225       barnes  varmint_grenade           50.0
# 7    223_rem            0.225       barnes  varmint_grenade           50.0
# 8    223_rem            0.225       barnes  varmint_grenade           50.0
# 9    223_rem            0.225       barnes  varmint_grenade           50.0
# 10   223_rem            0.225       barnes           mpg_fb           55.0
# 11   223_rem            0.225       barnes           mpg_fb           55.0
# 12   223_rem            0.225       barnes           mpg_fb           55.0
# 13   223_rem            0.225       barnes           mpg_fb           55.0
# 14   223_rem            0.225       barnes           mpg_fb           55.0
# 15   223_rem            0.225       barnes          ttsx_bt           55.0
# 16   223_rem            0.225       barnes          ttsx_bt           55.0
# 17   223_rem            0.225       barnes          ttsx_bt           55.0
# 18   223_rem            0.225       barnes          ttsx_bt           55.0
# 19   223_rem            0.225       barnes          ttsx_bt           55.0
#
#         powder_type  charge_weight  velocity_fps  barrel_length data_source  \
# 0   vihtavuori_n130           21.1          3402           25.0  vihtavuori
# 1   vihtavuori_n133           22.8          3481           25.0  vihtavuori
# 2   vihtavuori_n135           24.7          3514           25.0  vihtavuori
# 3   vihtavuori_n140           26.2          3425           25.0  vihtavuori
# 4   vihtavuori_n540           25.8          3301           25.0  vihtavuori
# 5   vihtavuori_n130           19.1          2877           25.0  vihtavuori
# 6   vihtavuori_n133           20.8          2959           25.0  vihtavuori
# 7   vihtavuori_n135           21.9          2976           25.0  vihtavuori
# 8   vihtavuori_n140           23.5          2963           25.0  vihtavuori
# 9   vihtavuori_n540           23.6          2920           25.0  vihtavuori
# 10  vihtavuori_n130           19.3          2785           25.0  vihtavuori
# 11  vihtavuori_n133           18.5          2726           25.0  vihtavuori
# 12  vihtavuori_n135           19.3          2746           25.0  vihtavuori
# 13  vihtavuori_n140           24.2          2910           25.0  vihtavuori
# 14  vihtavuori_n540           25.2          2920           25.0  vihtavuori
# 15  vihtavuori_n130           20.7          2881           25.0  vihtavuori
# 16  vihtavuori_n133           19.3          2818           25.0  vihtavuori
# 17  vihtavuori_n135           21.3          2877           25.0  vihtavuori
# 18  vihtavuori_n140           25.0          2966           25.0  vihtavuori
# 19  vihtavuori_n540           25.2          2963           25.0  vihtavuori
#
#                  primer  twist_rate   coal compressed_load  jump_to_lands  \
# 0   small_rifle_generic        12.0  2.181             NaN            NaN
# 1   small_rifle_generic        12.0  2.181             NaN            NaN
# 2   small_rifle_generic        12.0  2.181             NaN            NaN
# 3   small_rifle_generic        12.0  2.181             NaN            NaN
# 4   small_rifle_generic        12.0  2.181             NaN            NaN
# 5   small_rifle_generic        12.0  2.201             NaN            NaN
# 6   small_rifle_generic        12.0  2.201             NaN            NaN
# 7   small_rifle_generic        12.0  2.201             NaN            NaN
# 8   small_rifle_generic        12.0  2.201             NaN            NaN
# 9   small_rifle_generic        12.0  2.201             NaN            NaN
# 10  small_rifle_generic        12.0  2.165             NaN            NaN
# 11  small_rifle_generic        12.0  2.165             NaN            NaN
# 12  small_rifle_generic        12.0  2.165             NaN            NaN
# 13  small_rifle_generic        12.0  2.165             NaN            NaN
# 14  small_rifle_generic        12.0  2.165             NaN            NaN
# 15  small_rifle_generic        12.0  2.205             NaN            NaN
# 16  small_rifle_generic        12.0  2.205             NaN            NaN
# 17  small_rifle_generic        12.0  2.205             NaN            NaN
# 18  small_rifle_generic        12.0  2.205             NaN            NaN
# 19  small_rifle_generic        12.0  2.205             NaN            NaN
#
#     amb_temp  pressure  case_capacity suppressed
# 0        NaN       NaN            NaN        NaN
# 1        NaN       NaN            NaN        NaN
# 2        NaN       NaN            NaN        NaN
# 3        NaN       NaN            NaN        NaN
# 4        NaN       NaN            NaN        NaN
# 5        NaN       NaN            NaN        NaN
# 6        NaN       NaN            NaN        NaN
# 7        NaN       NaN            NaN        NaN
# 8        NaN       NaN            NaN        NaN
# 9        NaN       NaN            NaN        NaN
# 10       NaN       NaN            NaN        NaN
# 11       NaN       NaN            NaN        NaN
# 12       NaN       NaN            NaN        NaN
# 13       NaN       NaN            NaN        NaN
# 14       NaN       NaN            NaN        NaN
# 15       NaN       NaN            NaN        NaN
# 16       NaN       NaN            NaN        NaN
# 17       NaN       NaN            NaN        NaN
# 18       NaN       NaN            NaN        NaN
# 19       NaN       NaN            NaN        NaN

# %%
three_oh_eight = df[df["cartridge"].isin(["308_win"])].copy()
len(three_oh_eight)
# Out:
# 1254

# %%
three_oh_eight.head(20)
# Out:
#     cartridge  bullet_diameter bullet_brand     bullet_type  bullet_weight  \
# 945   308_win            0.308        lapua             als           57.0
# 946   308_win            0.308        lapua         g589_ot          100.0
# 947   308_win            0.308        lapua         g589_ot          100.0
# 948   308_win            0.308        lapua         g589_ot          100.0
# 949   308_win            0.308        lapua         g589_ot          100.0
# 950   308_win            0.308        lapua         g589_ot          100.0
# 951   308_win            0.308        lapua       hpce_otce          100.0
# 952   308_win            0.308        lapua       hpce_otce          100.0
# 953   308_win            0.308        lapua       hpce_otce          100.0
# 954   308_win            0.308        lapua       hpce_otce          100.0
# 955   308_win            0.308        lapua       hpce_otce          100.0
# 956   308_win            0.308        lapua       hpce_otce          100.0
# 957   308_win            0.308       barnes          tsx_fb          110.0
# 958   308_win            0.308       barnes          tsx_fb          110.0
# 959   308_win            0.308       barnes          tsx_fb          110.0
# 960   308_win            0.308       barnes          tsx_fb          110.0
# 961   308_win            0.308          fox  classic_hunter          110.0
# 962   308_win            0.308          fox  classic_hunter          110.0
# 963   308_win            0.308          fox  classic_hunter          110.0
# 964   308_win            0.308      hornady              cx          110.0
#
#          powder_type  charge_weight  velocity_fps  barrel_length data_source  \
# 945  vihtavuori_n110           27.5          3481           24.0  vihtavuori
# 946  vihtavuori_n120           33.6          2890           24.0  vihtavuori
# 947  vihtavuori_n130           37.8          2986           24.0  vihtavuori
# 948  vihtavuori_n133           41.7          3097           24.0  vihtavuori
# 949  vihtavuori_n135           43.2          3123           24.0  vihtavuori
# 950  vihtavuori_n540           47.4          3114           24.0  vihtavuori
# 951  vihtavuori_n110           20.4          2333           24.0  vihtavuori
# 952  vihtavuori_n120           30.6          2663           24.0  vihtavuori
# 953  vihtavuori_n130           33.7          2794           24.0  vihtavuori
# 954  vihtavuori_n133           40.6          3012           24.0  vihtavuori
# 955  vihtavuori_n530           41.4          3002           24.0  vihtavuori
# 956  vihtavuori_n135           38.1          2837           24.0  vihtavuori
# 957  vihtavuori_n130           38.0          2887           24.0  vihtavuori
# 958  vihtavuori_n133           41.7          2986           24.0  vihtavuori
# 959  vihtavuori_n530           43.5          2995           24.0  vihtavuori
# 960  vihtavuori_n135           43.2          2999           24.0  vihtavuori
# 961  vihtavuori_n133           37.0          2838           24.0  vihtavuori
# 962  vihtavuori_n135           39.7          2897           24.0  vihtavuori
# 963  vihtavuori_n140           46.3          3035           24.0  vihtavuori
# 964  vihtavuori_n130           38.3          2864           24.0  vihtavuori
#
#                   primer  twist_rate   coal compressed_load  jump_to_lands  \
# 945  large_rifle_generic        12.0  2.638             NaN            NaN
# 946  large_rifle_generic        12.0  2.638             NaN            NaN
# 947  large_rifle_generic        12.0  2.638             NaN            NaN
# 948  large_rifle_generic        12.0  2.638             NaN            NaN
# 949  large_rifle_generic        12.0  2.638             NaN            NaN
# 950  large_rifle_generic        12.0  2.638             NaN            NaN
# 951  large_rifle_generic        12.0  2.638             NaN            NaN
# 952  large_rifle_generic        12.0  2.638             NaN            NaN
# 953  large_rifle_generic        12.0  2.638             NaN            NaN
# 954  large_rifle_generic        12.0  2.638             NaN            NaN
# 955  large_rifle_generic        12.0  2.638             NaN            NaN
# 956  large_rifle_generic        12.0  2.638             NaN            NaN
# 957  large_rifle_generic        12.0  2.697             NaN            NaN
# 958  large_rifle_generic        12.0  2.697             NaN            NaN
# 959  large_rifle_generic        12.0  2.697             NaN            NaN
# 960  large_rifle_generic        12.0  2.697             NaN            NaN
# 961  large_rifle_generic        12.0  2.697             NaN            NaN
# 962  large_rifle_generic        12.0  2.697             NaN            NaN
# 963  large_rifle_generic        12.0  2.697             NaN            NaN
# 964  large_rifle_generic        12.0  2.795             NaN            NaN
#
#      amb_temp  pressure  case_capacity suppressed
# 945       NaN       NaN            NaN        NaN
# 946       NaN       NaN            NaN        NaN
# 947       NaN       NaN            NaN        NaN
# 948       NaN       NaN            NaN        NaN
# 949       NaN       NaN            NaN        NaN
# 950       NaN       NaN            NaN        NaN
# 951       NaN       NaN            NaN        NaN
# 952       NaN       NaN            NaN        NaN
# 953       NaN       NaN            NaN        NaN
# 954       NaN       NaN            NaN        NaN
# 955       NaN       NaN            NaN        NaN
# 956       NaN       NaN            NaN        NaN
# 957       NaN       NaN            NaN        NaN
# 958       NaN       NaN            NaN        NaN
# 959       NaN       NaN            NaN        NaN
# 960       NaN       NaN            NaN        NaN
# 961       NaN       NaN            NaN        NaN
# 962       NaN       NaN            NaN        NaN
# 963       NaN       NaN            NaN        NaN
# 964       NaN       NaN            NaN        NaN

# %%
features = ["charge_weight", "bullet_weight"]
target = ["velocity_fps"]
X = three_oh_eight[features].astype(float)
y = three_oh_eight[target].astype(float)

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
coeffs = pd.Series(model.coef_.ravel(), index=features)
intercept = model.intercept_
coeffs, intercept
# Out:
# (charge_weight    30.646965
#  bullet_weight    -7.501866
#  dtype: float64,
#  array([2506.86816771]))

# %% [markdown]
# ### As in previous baseline_zero, our sanity check appears to have passed.
# - Increasing charge weight increases velocity
# - Increasing bullet weight decreases velocity

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_pred = np.full_like(y, y.mean())
mae_zero = mean_absolute_error(y, mean_pred)  # floor mae

preds = model.predict(X)
mae_one = mean_absolute_error(y, preds)  # mae based on model learning from our two features

mae_zero, mae_one
# Out:
# (191.9525982565519, 72.89076409368025)

# %%
import matplotlib.pyplot as plt

residuals = y - preds

plt.scatter(preds, residuals)
plt.axhline(0)
plt.xlabel("Predicted velocity (ft/s)")
plt.ylabel("Residual (ft/s)")
plt.title(".308 Winchester Baseline-1.v2 Residuals")
plt.show()

# %% [markdown]
# ### Results are now becoming meaningful
# - Regression model is showing a significantly lower mean error over the floor using only two features.
# - Residual plot is behaving as desired: residuals are centered near zero so no gross bias, wide vertical spread due to lack of context/variables
# - Wider residual spread at higher velocities line up with heteroscedasticity. Low to moderate velocities are easier for the model to predict more accurately, higher velocity combinations are more difficult to accurately model with limited features. *It will be interesting to see how the higher velocity residuals shift as things like barrel length and powder burn rates are introduced to the model.*
